# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Palak\Downloads\HR Project\data\raw_data.csv.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
import os
os.listdir(r"C:\Users\Palak\Downloads\HR Project\data")
# Out:
# ['raw_data.csv.csv']

# %%
df = pd.read_csv(r"C:\Users\Palak\Downloads\HR Project\data\raw_data.csv.csv")

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.duplicated().sum()
df = df.drop_duplicates()

# %%
df['Attrition'] = df['Attrition'].map({'Yes':1, 'No':0})

# %%
df.drop(['EmployeeCount','Over18','StandardHours'], axis=1, inplace=True)

# %%
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].str.strip()

# %%
df['SalaryBand'] = pd.cut(
    df['MonthlyIncome'],
    bins=[0,3000,6000,10000,20000],
    labels=['Low','Medium','High','Very High']
)

# %%
df['AgeGroup'] = pd.cut(
    df['Age'],
    bins=[18,25,35,50,60],
    labels=['18-25','26-35','36-50','50+']
)

# %%
df.to_csv("../data/cleaned_data.csv", index=False)

# %%
df['Attrition'].mean() * 100
# Out:
# np.float64(16.122448979591837)

# %%
df.groupby('Department')['Attrition'].mean()
# Out:
# Department
# Human Resources           0.190476
# Research & Development    0.138398
# Sales                     0.206278
# Name: Attrition, dtype: float64

# %%
df.groupby('SalaryBand')['Attrition'].mean()
# Out:
# C:\Users\Palak\AppData\Local\Temp\ipykernel_48168\2709782578.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('SalaryBand')['Attrition'].mean()
# SalaryBand
# Low          0.286076
# Medium       0.127168
# High         0.120000
# Very High    0.088968
# Name: Attrition, dtype: float64

# %%
df.groupby('OverTime')['Attrition'].mean()
# Out:
# OverTime
# No     0.104364
# Yes    0.305288
# Name: Attrition, dtype: float64

# %%
df['RiskScore'] = (
    (df['OverTime'] == 'Yes') * 0.3 +
    (df['MonthlyIncome'] < 5000) * 0.2 +
    (df['JobSatisfaction'] <= 2) * 0.3 +
    (df['YearsAtCompany'] < 3) * 0.2
)

# %%
df['RiskLevel'] = pd.cut(
    df['RiskScore'],
    bins=[0,0.3,0.6,1],
    labels=['Low','Medium','High']
)

# %%
df.to_csv("../data/cleaned_data.csv", index=False)
